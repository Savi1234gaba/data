# %% [markdown]
# <a href="https://colab.research.google.com/github/Savi1234gaba/data/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import package
import pandas as pd
import numpy as np

# Version of pandas
pd.__version__
# Out:
# '2.2.2'

# %%
# Our first series
number_series = pd.Series ([2, 3, 5, 6, 8])
print(number_series)
# Out:
# 0    2
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
# Same series but with different indices
number_series = pd.Series([2, 3, 5, 6, 8],index=['a', 'b', 'd', 'e', 'f'],name='Number')
print(number_series)
# Out:
# a    2
# b    3
# d    5
# e    6
# f    8
# Name: Number, dtype: int64

# %%
print(number_series[0])
print(number_series['a'])
# Out:
# 2
# 2
# <ipython-input-6-43cc7e55b50e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(number_series[0])

# %%
# Creating our first DataFrame
some_2D_array = np.random.randint(4, 6,(3, 4))
first_dataframe = pd.DataFrame(some_2D_array , columns=['Akshay','Devashish','Divy','Monika'])
first_dataframe
# Out:
#    Akshay  Devashish  Divy  Monika
# 0       4          5     5       5
# 1       5          4     5       5
# 2       5          4     4       4

# %%
# Lets create the same dataframe but different indices
import pandas as pd
another_data_frame = pd.DataFrame(some_2D_array, columns=['A','B','C','D'],index = ['First','Second','Third'])
another_data_frame
# Out:
#         A  B  C  D
# First   4  5  5  5
# Second  5  4  5  5
# Third   5  4  4  4

# %%
# Initialize list of lists
list_of_lists = [['Amar', 10], ['Akhbar', 15], ['Anthony', 14]]

# Import pandas
import pandas as pd #Importing pandas and aliasing it to 'pd'

# Create the pandas DataFrame
df = pd.DataFrame(list_of_lists, columns = ['Name', 'Age'])

# Print dataframe
df
# Out:
#       Name  Age
# 0     Amar   10
# 1   Akhbar   15
# 2  Anthony   14

# %%
# Store the data in a dictionary
employee_dict = {'Employee Name':['Rajeev', 'Sumit', 'Aviral'], 'Income':[200000, 140000, 90000]}

# Create DataFrame
employee_df = pd.DataFrame(employee_dict)

# Print the dataframe
employee_df
# Out:
#   Employee Name  Income
# 0        Rajeev  200000
# 1         Sumit  140000
# 2        Aviral   90000

# %%
# Store the data in a dictionary
series_dict = {'First Series' : pd.Series([10, 20, 30, 40]),
               'Second Series' : pd.Series([10, 20, 30, 40])}

# Create the DataFrame using the dictionary
df = pd.DataFrame(series_dict)

# Print the dataframe
df
# Out:
#    First Series  Second Series
# 0            10             10
# 1            20             20
# 2            30             30
# 3            40             40

# %%
# Initialise the list of dictionaries
list_of_dicts = [{'a': 1, 'b': 2, 'c': 3}, {'a':10, 'b' : 20, 'c' : 30}]

# Create the DataFrame
df = pd.DataFrame(list_of_dicts)

# Print the dataframe
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
# what happens if the number of keys are different in the two dictionaries
list_of_dicts = [{'a': 2, 'c': 3}, {'a': 10, 'b': 20, 'c': 30}]
df = pd.DataFrame(list_of_dicts, index =['first', 'second'])
df
# Out:
#          a   c     b
# first    2   3   NaN
# second  10  30  20.0

# %%
# List of names
actor_names = ['Ryan Reynolds', 'Benedict Cumberbatch', 'Rober Downey Jr.', 'Chris Evans']

# Import numpy
import numpy as np # Importing numpy and aliasing it to 'np'

# List of their ages
actor_ages = [48,62,54,np.nan ]

# Get the list of tuples by zipping the two lists together
list_of_tuples = list(zip(actor_names, actor_ages))

# Conerting the list of tuples into pandas DataFrame
actor_df = pd.DataFrame(list_of_tuples, columns = ['Name', 'Age'])

# Print the dataframe
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2      Rober Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
list(actor_df.index)
# Out:
# [0, 1, 2, 3]

# %%
# Create an array of shape (3,5)
our_array = np.random.randn(3,5)
df = pd.DataFrame(our_array, columns=['A','B','C','D','E',])
df
# Out:
#           A         B         C         D         E
# 0 -0.398097 -0.031350  2.560497  1.363602  0.489274
# 1  0.662660 -0.884695 -0.085639 -1.047817 -0.907750
# 2  0.446653 -0.897528 -1.460636  0.735170  0.247687

# %%
# We can use the head() method
df.head()
# Out:
#           A         B         C         D         E
# 0 -0.398097 -0.031350  2.560497  1.363602  0.489274
# 1  0.662660 -0.884695 -0.085639 -1.047817 -0.907750
# 2  0.446653 -0.897528 -1.460636  0.735170  0.247687

# %%
# In fact we can also print the first 10 rows
df.head(1)
# Out:
#           A        B         C         D         E
# 0 -0.398097 -0.03135  2.560497  1.363602  0.489274

# %%
df.tail()
# Out:
#           A         B         C         D         E
# 0 -0.398097 -0.031350  2.560497  1.363602  0.489274
# 1  0.662660 -0.884695 -0.085639 -1.047817 -0.907750
# 2  0.446653 -0.897528 -1.460636  0.735170  0.247687

# %%
df.tail(1)
# Out:
#           A         B         C        D         E
# 2  0.446653 -0.897528 -1.460636  0.73517  0.247687

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list(actor_df.columns)
# Out:
# ['Name', 'Age']

# %%
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2      Rober Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
df1=actor_df.rename(columns = {'Name':'Actor Name','Age' :'Actor Age'}, inplace=False)

# actor_df
df1
# Out:
#              Actor Name  Actor Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       62.0
# 2      Rober Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
employee_df
# Out:
#   Employee Name  Income
# 0        Rajeev  200000
# 1         Sumit  140000
# 2        Aviral   90000

# %%
employee_df.rename(columns = {'Employee Name':'Name'}, inplace=True)

employee_df
# Out:
#      Name  Income
# 0  Rajeev  200000
# 1   Sumit  140000
# 2  Aviral   90000

# %%
employee_df = employee_df.rename({'Employee Name':'Name'},axis=1)

employee_df
# Out:
#      Name  Income
# 0  Rajeev  200000
# 1   Sumit  140000
# 2  Aviral   90000
